# %%
import pandas as pd
import numpy as np
import nltk
import re
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
import sklearn.metrics as metrics
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization
from tensorflow.data import Dataset
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.models import Sequential
from keras.preprocessing import sequence
import gensim.downloader as api
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.utils import compute_class_weight
from sklearn import set_config

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
set_config(display="diagram")
sns.set(rc = {'figure.figsize':(15,8)})
sns.set_style("ticks")

# %%
def build_tokenizer(texts):
    tokenizer = tf.keras.preprocessing.text.Tokenizer()
    tokenizer.fit_on_texts(texts)
    return tokenizer

def preprocess_texts(texts, tokenizer):
    text_sequences = tokenizer.texts_to_sequences(texts)
    text_sequences = tf.keras.preprocessing.sequence.pad_sequences(text_sequences)
    return text_sequences

def preprocess_labels(labels):
    characters = labels.value_counts().index
    lookup = {index:character for character,index in enumerate(characters)}
    labels = [lookup[label] for label in labels]
    return tf.keras.utils.to_categorical(labels, len(characters))

def build_vocab(tokenizer):
    word2idx = tokenizer.word_index
    idx2word = {v:k for k, v in word2idx.items()}
    word2idx["PAD"] = 0
    idx2word[0] = "PAD"
    return word2idx, idx2word

def build_datasets(text, labels):
    num_records = len(text)
    dataset = tf.data.Dataset.from_tensor_slices((text, labels))
    dataset = dataset.shuffle(num_records)
    test_size = num_records // 4
    val_size = (num_records - test_size) // 10
    test = dataset.take(test_size)
    val = dataset.skip(test_size).take(val_size)
    train = dataset.skip(test_size + val_size)
    return batch_datasets(train, test, val)

def batch_datasets(*datasets, batch_size=32):
    return (dataset.batch(batch_size, drop_remainder=True) for dataset in datasets)

def build_embedding_matrix(sequences, word2idx, embedding_dim, word_vectors):
    vocab_size = len(word2idx)
    matrix = np.zeros((vocab_size, embedding_dim))
    for word, idx in word2idx.items():
        try:
            matrix[idx] = word_vectors.word_vec(word)
        except KeyError: # word not in embedding
            pass
    return matrix

def get_char_lookup(characters):
    characters = characters.value_counts().index
    return {character:index for character,index in enumerate(characters)}

def get_predictions(dataset, model):
    labels, predictions = [], []
    for X_test, Y_test in dataset:
        pred = model.predict_on_batch(X_test)
        argmax_test = np.argmax(Y_test, axis=1)
        argmax_pred = np.argmax(pred, axis=1)
        labels.extend(argmax_test.tolist())
        predictions.extend(argmax_pred.tolist())
    return labels, predictions

def get_class_weights(labels):
    target_names = labels.value_counts().index.to_list()
    class_weights = compute_class_weight(class_weight='balanced', classes=target_names, y=labels)
    indexes = list(range(len(target_names)))
    return dict(zip(indexes, class_weights))

def plot_history(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 2.5)
    plt.show()

def plot_confusion_matrix(labels, predictions, target_names):
    return metrics.ConfusionMatrixDisplay.from_predictions(
        labels,
        predictions,
        cmap="Blues",
        xticks_rotation="vertical",
        display_labels=target_names
    )

# %%
def build_model(**kwargs):
    model = Sequential()
    model.add(
        tf.keras.layers.Embedding(
            kwargs["vocab_size"], 
            kwargs["embed_size"],
            input_length=kwargs["input_length"],
            trainable=True
        )
    )
    model.add(
        tf.keras.layers.SpatialDropout1D(0.2)
    )
    model.add(
        tf.keras.layers.Conv1D(
            filters=kwargs["num_filters"],
            kernel_size=kwargs["kernel_size"],
            activation="relu"
        )
    )
    model.add(
        tf.keras.layers.GlobalMaxPooling1D()
    )
    model.add(
        tf.keras.layers.Dense(
            kwargs["output_size"],
            activation="softmax"
        )
    )
    model.build(input_shape=(None, kwargs["input_length"]))
    model.compile(
        optimizer="adam",
        loss="categorical_crossentropy",
        metrics=["categorical_accuracy"]
    )
    return model

# %%
def train_and_evaluate(show_name, word_vectors, epochs=20, embedding_size=300, output_size=10):
    show = pd.read_csv(f"/content/drive/MyDrive/star_trek_data/{show_name}.csv", index_col=None, engine="python").dropna()
    char_lookup = get_char_lookup(show["Character"])
    class_weights = get_class_weights(show["Character"])
    tokenizer = build_tokenizer(list(show["Lines"]))
    text_sequences = preprocess_texts(show["Lines"], tokenizer)
    cat_labels = preprocess_labels(show["Character"])
    word2idx, idx2word = build_vocab(tokenizer)
    train, test, val = build_datasets(text_sequences, cat_labels)
    embed_mat = build_embedding_matrix(text_sequences, word2idx, embedding_size, word_vectors)
    model = build_model(
        vocab_size=len(word2idx),
        embed_size=embedding_size,
        input_length=len(text_sequences[0]),
        num_filters=256,
        kernel_size=3,
        output_size=output_size,
        embed_mat=embed_mat
    )
    print(model.summary())
    history = model.fit(
        train,
        epochs=epochs,
        validation_data=val,
        class_weight=class_weights,
    )
    labels, predictions = get_predictions(test, model)
    target_names = show["Character"].value_counts().index.to_list()
    return labels, predictions, target_names, history

# %%
word_vectors = api.load("glove-wiki-gigaword-300")

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **The Original Series**

# %%
labels, predictions, target_names, history = train_and_evaluate("TOS", word_vectors)
print(classification_report(labels, predictions, target_names=target_names))
print(plot_confusion_matrix(labels, predictions, target_names))
plot_history(history)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 183, 300)          3219900
#
#  spatial_dropout1d (SpatialD  (None, 183, 300)         0
#  ropout1D)
#
#  conv1d (Conv1D)             (None, 181, 256)          230656
#
#  global_max_pooling1d (Globa  (None, 256)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 10)                2570
#
# =================================================================
# Total params: 3,453,126
# Trainable params: 3,453,126
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 413/413 [==============================] - 7s 12ms/step - loss: 2.0703 - categorical_accuracy: 0.2151 - val_loss: 1.7512 - val_categorical_accuracy: 0.4076
# Epoch 2/20
# 413/413 [==============================] - 5s 11ms/step - loss: 1.5385 - categorical_accuracy: 0.4565 - val_loss: 1.2652 - val_categorical_accuracy: 0.6132
# Epoch 3/20
# 413/413 [==============================] - 4s 9ms/step - loss: 1.1080 - categorical_accuracy: 0.5738 - val_loss: 1.0777 - val_categorical_accuracy: 0.6528
# Epoch 4/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.8025 - categorical_accuracy: 0.6643 - val_loss: 0.8870 - val_categorical_accuracy: 0.7208
# Epoch 5/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.6160 - categorical_accuracy: 0.7205 - val_loss: 0.6334 - val_categorical_accuracy: 0.7986
# Epoch 6/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.5209 - categorical_accuracy: 0.7654 - val_loss: 0.6263 - val_categorical_accuracy: 0.8028
# Epoch 7/20
# 413/413 [==============================] - 3s 8ms/step - loss: 0.4175 - categorical_accuracy: 0.8049 - val_loss: 0.5166 - val_categorical_accuracy: 0.8257
# Epoch 8/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.3656 - categorical_accuracy: 0.8267 - val_loss: 0.4675 - val_categorical_accuracy: 0.8507
# Epoch 9/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.3170 - categorical_accuracy: 0.8517 - val_loss: 0.4025 - val_categorical_accuracy: 0.8597
# Epoch 10/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.2930 - categorical_accuracy: 0.8659 - val_loss: 0.3086 - val_categorical_accuracy: 0.9076
# Epoch 11/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.2466 - categorical_accuracy: 0.8828 - val_loss: 0.2970 - val_categorical_accuracy: 0.9069
# Epoch 12/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.2654 - categorical_accuracy: 0.8888 - val_loss: 0.2810 - val_categorical_accuracy: 0.9132
# Epoch 13/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.2305 - categorical_accuracy: 0.9004 - val_loss: 0.2521 - val_categorical_accuracy: 0.9181
# Epoch 14/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.2171 - categorical_accuracy: 0.9105 - val_loss: 0.2108 - val_categorical_accuracy: 0.9347
# Epoch 15/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.2040 - categorical_accuracy: 0.9163 - val_loss: 0.1843 - val_categorical_accuracy: 0.9410
# Epoch 16/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.1892 - categorical_accuracy: 0.9233 - val_loss: 0.2042 - val_categorical_accuracy: 0.9361
# Epoch 17/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.1993 - categorical_accuracy: 0.9206 - val_loss: 0.2016 - val_categorical_accuracy: 0.9354
# Epoch 18/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.2016 - categorical_accuracy: 0.9272 - val_loss: 0.1957 - val_categorical_accuracy: 0.9306
# Epoch 19/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.1869 - categorical_accuracy: 0.9262 - val_loss: 0.2151 - val_categorical_accuracy: 0.9278
# Epoch 20/20
# 413/413 [==============================] - 3s 7ms/step - loss: 0.1817 - categorical_accuracy: 0.9298 - val_loss: 0.1775 - val_categorical_accuracy: 0.9444
#               precision    recall  f1-score   support
#
#         KIRK       0.99      0.94      0.96      2336
#        SPOCK       0.98      0.94      0.96      1145
#        MCCOY       0.93      0.95      0.94       601
#        SCOTT       0.91      0.93      0.92       319
#         SULU       0.97      0.89      0.93       160
#        UHURA       0.75      0.89      0.82       142
#       CHEKOV       0.47      0.94      0.63        78
#         PIKE       0.89      1.00      0.94        49
#         MUDD       0.76      1.00      0.86        35
#       CHAPEL       0.38      0.87      0.52        31
#
#     accuracy                           0.94      4896
#    macro avg       0.80      0.93      0.85      4896
# weighted avg       0.95      0.94      0.94      4896
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f0034f93fd0>

# %% [markdown]
# **The Next Generation**

# %%
labels, predictions, target_names, history = train_and_evaluate("TNG", word_vectors)
print(classification_report(labels, predictions, target_names=target_names))
print(plot_confusion_matrix(labels, predictions, target_names))
plot_history(history)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 384, 300)          4830900
#
#  spatial_dropout1d_1 (Spatia  (None, 384, 300)         0
#  lDropout1D)
#
#  conv1d_1 (Conv1D)           (None, 382, 256)          230656
#
#  global_max_pooling1d_1 (Glo  (None, 256)              0
#  balMaxPooling1D)
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 5,064,126
# Trainable params: 5,064,126
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 882/882 [==============================] - 10s 11ms/step - loss: 2.0411 - categorical_accuracy: 0.2627 - val_loss: 1.7184 - val_categorical_accuracy: 0.4047
# Epoch 2/20
# 882/882 [==============================] - 10s 11ms/step - loss: 1.6450 - categorical_accuracy: 0.4065 - val_loss: 1.4481 - val_categorical_accuracy: 0.4978
# Epoch 3/20
# 882/882 [==============================] - 10s 11ms/step - loss: 1.3359 - categorical_accuracy: 0.5089 - val_loss: 1.1729 - val_categorical_accuracy: 0.6097
# Epoch 4/20
# 882/882 [==============================] - 10s 11ms/step - loss: 1.0939 - categorical_accuracy: 0.5828 - val_loss: 1.0410 - val_categorical_accuracy: 0.6470
# Epoch 5/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.9047 - categorical_accuracy: 0.6447 - val_loss: 0.8269 - val_categorical_accuracy: 0.7082
# Epoch 6/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.7582 - categorical_accuracy: 0.6892 - val_loss: 0.7657 - val_categorical_accuracy: 0.7455
# Epoch 7/20
# 882/882 [==============================] - 11s 12ms/step - loss: 0.6560 - categorical_accuracy: 0.7251 - val_loss: 0.6423 - val_categorical_accuracy: 0.7816
# Epoch 8/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.5802 - categorical_accuracy: 0.7521 - val_loss: 0.5692 - val_categorical_accuracy: 0.8119
# Epoch 9/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.5105 - categorical_accuracy: 0.7815 - val_loss: 0.5041 - val_categorical_accuracy: 0.8243
# Epoch 10/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.4672 - categorical_accuracy: 0.7994 - val_loss: 0.4327 - val_categorical_accuracy: 0.8444
# Epoch 11/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.4323 - categorical_accuracy: 0.8121 - val_loss: 0.4142 - val_categorical_accuracy: 0.8597
# Epoch 12/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3993 - categorical_accuracy: 0.8251 - val_loss: 0.4119 - val_categorical_accuracy: 0.8600
# Epoch 13/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3759 - categorical_accuracy: 0.8356 - val_loss: 0.3738 - val_categorical_accuracy: 0.8731
# Epoch 14/20
# 882/882 [==============================] - 11s 12ms/step - loss: 0.3516 - categorical_accuracy: 0.8458 - val_loss: 0.4652 - val_categorical_accuracy: 0.8367
# Epoch 15/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3252 - categorical_accuracy: 0.8561 - val_loss: 0.3218 - val_categorical_accuracy: 0.8798
# Epoch 16/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3254 - categorical_accuracy: 0.8552 - val_loss: 0.3181 - val_categorical_accuracy: 0.8865
# Epoch 17/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3159 - categorical_accuracy: 0.8634 - val_loss: 0.2850 - val_categorical_accuracy: 0.9018
# Epoch 18/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3084 - categorical_accuracy: 0.8660 - val_loss: 0.3142 - val_categorical_accuracy: 0.8881
# Epoch 19/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3007 - categorical_accuracy: 0.8729 - val_loss: 0.3158 - val_categorical_accuracy: 0.8954
# Epoch 20/20
# 882/882 [==============================] - 10s 11ms/step - loss: 0.3019 - categorical_accuracy: 0.8716 - val_loss: 0.2845 - val_categorical_accuracy: 0.9015
#               precision    recall  f1-score   support
#
#       PICARD       0.96      0.89      0.93      2984
#        RIKER       0.94      0.86      0.90      1860
#         DATA       0.97      0.90      0.93      1519
#      LAFORGE       0.88      0.92      0.90      1040
#         WORF       0.91      0.88      0.89       940
#      CRUSHER       0.90      0.90      0.90       766
#         TROI       0.78      0.92      0.84       743
#       WESLEY       0.62      0.88      0.73       321
#            Q       0.80      0.98      0.88       139
#        TASHA       0.41      0.97      0.57       120
#
#     accuracy                           0.89     10432
#    macro avg       0.82      0.91      0.85     10432
# weighted avg       0.91      0.89      0.90     10432
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7eff9865cb50>

# %% [markdown]
# **Deep Space Nine**

# %%
labels, predictions, target_names, history = train_and_evaluate("DS9", word_vectors)
print(classification_report(labels, predictions, target_names=target_names))
print(plot_confusion_matrix(labels, predictions, target_names))
plot_history(history)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 300, 300)          4545000
#
#  spatial_dropout1d_2 (Spatia  (None, 300, 300)         0
#  lDropout1D)
#
#  conv1d_2 (Conv1D)           (None, 298, 256)          230656
#
#  global_max_pooling1d_2 (Glo  (None, 256)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 4,778,226
# Trainable params: 4,778,226
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 855/855 [==============================] - 9s 9ms/step - loss: 2.1338 - categorical_accuracy: 0.1763 - val_loss: 1.9215 - val_categorical_accuracy: 0.3293
# Epoch 2/20
# 855/855 [==============================] - 8s 9ms/step - loss: 1.8205 - categorical_accuracy: 0.3236 - val_loss: 1.6256 - val_categorical_accuracy: 0.4451
# Epoch 3/20
# 855/855 [==============================] - 8s 9ms/step - loss: 1.5677 - categorical_accuracy: 0.4212 - val_loss: 1.3873 - val_categorical_accuracy: 0.5299
# Epoch 4/20
# 855/855 [==============================] - 8s 9ms/step - loss: 1.3400 - categorical_accuracy: 0.5013 - val_loss: 1.2014 - val_categorical_accuracy: 0.5938
# Epoch 5/20
# 855/855 [==============================] - 8s 9ms/step - loss: 1.1546 - categorical_accuracy: 0.5607 - val_loss: 1.0281 - val_categorical_accuracy: 0.6487
# Epoch 6/20
# 855/855 [==============================] - 8s 9ms/step - loss: 1.0007 - categorical_accuracy: 0.6160 - val_loss: 0.9114 - val_categorical_accuracy: 0.6895
# Epoch 7/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.8842 - categorical_accuracy: 0.6620 - val_loss: 0.7654 - val_categorical_accuracy: 0.7451
# Epoch 8/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.7920 - categorical_accuracy: 0.6959 - val_loss: 0.6739 - val_categorical_accuracy: 0.7740
# Epoch 9/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.7098 - categorical_accuracy: 0.7254 - val_loss: 0.5992 - val_categorical_accuracy: 0.8132
# Epoch 10/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.6485 - categorical_accuracy: 0.7480 - val_loss: 0.5754 - val_categorical_accuracy: 0.8102
# Epoch 11/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.6023 - categorical_accuracy: 0.7650 - val_loss: 0.5144 - val_categorical_accuracy: 0.8306
# Epoch 12/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.5588 - categorical_accuracy: 0.7806 - val_loss: 0.4997 - val_categorical_accuracy: 0.8342
# Epoch 13/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.5355 - categorical_accuracy: 0.7921 - val_loss: 0.4372 - val_categorical_accuracy: 0.8586
# Epoch 14/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4954 - categorical_accuracy: 0.8086 - val_loss: 0.4530 - val_categorical_accuracy: 0.8454
# Epoch 15/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4827 - categorical_accuracy: 0.8126 - val_loss: 0.4258 - val_categorical_accuracy: 0.8533
# Epoch 16/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4629 - categorical_accuracy: 0.8188 - val_loss: 0.4258 - val_categorical_accuracy: 0.8536
# Epoch 17/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4528 - categorical_accuracy: 0.8234 - val_loss: 0.3925 - val_categorical_accuracy: 0.8609
# Epoch 18/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4223 - categorical_accuracy: 0.8332 - val_loss: 0.3746 - val_categorical_accuracy: 0.8727
# Epoch 19/20
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4158 - categorical_accuracy: 0.8365 - val_loss: 0.3690 - val_categorical_accuracy: 0.8753
# Epoch 20/20
# 855/855 [==============================] - 8s 10ms/step - loss: 0.4080 - categorical_accuracy: 0.8422 - val_loss: 0.3565 - val_categorical_accuracy: 0.8770
#               precision    recall  f1-score   support
#
#        SISKO       0.93      0.85      0.89      2170
#         KIRA       0.92      0.82      0.87      1262
#       BASHIR       0.95      0.86      0.91      1195
#      O'BRIEN       0.87      0.88      0.88      1190
#          ODO       0.88      0.88      0.88      1124
#        QUARK       0.91      0.91      0.91      1042
#          DAX       0.91      0.91      0.91       936
#         WORF       0.81      0.93      0.87       480
#        GARAK       0.74      0.95      0.83       357
#         JAKE       0.55      0.96      0.70       356
#
#     accuracy                           0.88     10112
#    macro avg       0.85      0.90      0.86     10112
# weighted avg       0.89      0.88      0.88     10112
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f003526e3d0>

# %% [markdown]
# **Voyager**

# %%
labels, predictions, target_names, history = train_and_evaluate("VOY", word_vectors)
print(classification_report(labels, predictions, target_names=target_names))
print(plot_confusion_matrix(labels, predictions, target_names))
plot_history(history)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 219, 300)          5006700
#
#  spatial_dropout1d_3 (Spatia  (None, 219, 300)         0
#  lDropout1D)
#
#  conv1d_3 (Conv1D)           (None, 217, 256)          230656
#
#  global_max_pooling1d_3 (Glo  (None, 256)              0
#  balMaxPooling1D)
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 5,239,926
# Trainable params: 5,239,926
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 2.0896 - categorical_accuracy: 0.2258 - val_loss: 1.7704 - val_categorical_accuracy: 0.3898
# Epoch 2/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 1.7742 - categorical_accuracy: 0.3591 - val_loss: 1.6016 - val_categorical_accuracy: 0.4468
# Epoch 3/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 1.5299 - categorical_accuracy: 0.4560 - val_loss: 1.2812 - val_categorical_accuracy: 0.5628
# Epoch 4/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 1.3067 - categorical_accuracy: 0.5335 - val_loss: 1.0921 - val_categorical_accuracy: 0.6458
# Epoch 5/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 1.1166 - categorical_accuracy: 0.5982 - val_loss: 0.9425 - val_categorical_accuracy: 0.6952
# Epoch 6/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.9706 - categorical_accuracy: 0.6461 - val_loss: 0.8444 - val_categorical_accuracy: 0.7160
# Epoch 7/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.8445 - categorical_accuracy: 0.6894 - val_loss: 0.7053 - val_categorical_accuracy: 0.7632
# Epoch 8/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.7477 - categorical_accuracy: 0.7224 - val_loss: 0.6534 - val_categorical_accuracy: 0.7807
# Epoch 9/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.6754 - categorical_accuracy: 0.7513 - val_loss: 0.5559 - val_categorical_accuracy: 0.8213
# Epoch 10/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.6188 - categorical_accuracy: 0.7693 - val_loss: 0.4938 - val_categorical_accuracy: 0.8432
# Epoch 11/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.5748 - categorical_accuracy: 0.7845 - val_loss: 0.5005 - val_categorical_accuracy: 0.8317
# Epoch 12/20
# 1027/1027 [==============================] - 9s 9ms/step - loss: 0.5369 - categorical_accuracy: 0.8006 - val_loss: 0.4771 - val_categorical_accuracy: 0.8339
# Epoch 13/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.5192 - categorical_accuracy: 0.8053 - val_loss: 0.4070 - val_categorical_accuracy: 0.8632
# Epoch 14/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.4835 - categorical_accuracy: 0.8196 - val_loss: 0.3862 - val_categorical_accuracy: 0.8698
# Epoch 15/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.4734 - categorical_accuracy: 0.8213 - val_loss: 0.4043 - val_categorical_accuracy: 0.8553
# Epoch 16/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.4516 - categorical_accuracy: 0.8301 - val_loss: 0.3964 - val_categorical_accuracy: 0.8673
# Epoch 17/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.4387 - categorical_accuracy: 0.8347 - val_loss: 0.3420 - val_categorical_accuracy: 0.8786
# Epoch 18/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.4307 - categorical_accuracy: 0.8394 - val_loss: 0.3533 - val_categorical_accuracy: 0.8783
# Epoch 19/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.4208 - categorical_accuracy: 0.8404 - val_loss: 0.3446 - val_categorical_accuracy: 0.8791
# Epoch 20/20
# 1027/1027 [==============================] - 9s 8ms/step - loss: 0.4046 - categorical_accuracy: 0.8472 - val_loss: 0.3449 - val_categorical_accuracy: 0.8819
#               precision    recall  f1-score   support
#
#      JANEWAY       0.96      0.87      0.91      2867
#     CHAKOTAY       0.90      0.87      0.88      1395
#          EMH       0.91      0.90      0.91      1376
#        PARIS       0.89      0.89      0.89      1208
#        TUVOK       0.90      0.90      0.90      1085
#          KIM       0.90      0.86      0.88      1070
#       TORRES       0.87      0.88      0.87      1018
#        SEVEN       0.84      0.92      0.88      1046
#       NEELIX       0.81      0.93      0.87       799
#          KES       0.60      0.90      0.72       296
#
#     accuracy                           0.89     12160
#    macro avg       0.86      0.89      0.87     12160
# weighted avg       0.89      0.89      0.89     12160
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7effb2e71550>

# %% [markdown]
# **Enterprise**

# %%
labels, predictions, target_names, history = train_and_evaluate("ENT", word_vectors)
print(classification_report(labels, predictions, target_names=target_names))
print(plot_confusion_matrix(labels, predictions, target_names))
plot_history(history)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 265, 300)          3385500
#
#  spatial_dropout1d_4 (Spatia  (None, 265, 300)         0
#  lDropout1D)
#
#  conv1d_4 (Conv1D)           (None, 263, 256)          230656
#
#  global_max_pooling1d_4 (Glo  (None, 256)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 3,618,726
# Trainable params: 3,618,726
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 528/528 [==============================] - 5s 9ms/step - loss: 2.2278 - categorical_accuracy: 0.1473 - val_loss: 1.9469 - val_categorical_accuracy: 0.3281
# Epoch 2/20
# 528/528 [==============================] - 5s 9ms/step - loss: 1.8101 - categorical_accuracy: 0.3324 - val_loss: 1.7002 - val_categorical_accuracy: 0.4122
# Epoch 3/20
# 528/528 [==============================] - 5s 9ms/step - loss: 1.4226 - categorical_accuracy: 0.4364 - val_loss: 1.3772 - val_categorical_accuracy: 0.5318
# Epoch 4/20
# 528/528 [==============================] - 5s 9ms/step - loss: 1.1498 - categorical_accuracy: 0.5261 - val_loss: 1.1301 - val_categorical_accuracy: 0.6137
# Epoch 5/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.9018 - categorical_accuracy: 0.6010 - val_loss: 0.9598 - val_categorical_accuracy: 0.6735
# Epoch 6/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.7421 - categorical_accuracy: 0.6502 - val_loss: 0.8571 - val_categorical_accuracy: 0.7166
# Epoch 7/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.6264 - categorical_accuracy: 0.6979 - val_loss: 0.6639 - val_categorical_accuracy: 0.7726
# Epoch 8/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.5545 - categorical_accuracy: 0.7312 - val_loss: 0.6108 - val_categorical_accuracy: 0.7915
# Epoch 9/20
# 528/528 [==============================] - 5s 10ms/step - loss: 0.4914 - categorical_accuracy: 0.7583 - val_loss: 0.6090 - val_categorical_accuracy: 0.7888
# Epoch 10/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.4470 - categorical_accuracy: 0.7785 - val_loss: 0.5203 - val_categorical_accuracy: 0.8308
# Epoch 11/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.4010 - categorical_accuracy: 0.7955 - val_loss: 0.4699 - val_categorical_accuracy: 0.8378
# Epoch 12/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.3787 - categorical_accuracy: 0.8113 - val_loss: 0.4701 - val_categorical_accuracy: 0.8432
# Epoch 13/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.3519 - categorical_accuracy: 0.8285 - val_loss: 0.4087 - val_categorical_accuracy: 0.8556
# Epoch 14/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.3233 - categorical_accuracy: 0.8379 - val_loss: 0.3677 - val_categorical_accuracy: 0.8815
# Epoch 15/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.3153 - categorical_accuracy: 0.8468 - val_loss: 0.3683 - val_categorical_accuracy: 0.8745
# Epoch 16/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2978 - categorical_accuracy: 0.8585 - val_loss: 0.3716 - val_categorical_accuracy: 0.8685
# Epoch 17/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2922 - categorical_accuracy: 0.8593 - val_loss: 0.3242 - val_categorical_accuracy: 0.8863
# Epoch 18/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2771 - categorical_accuracy: 0.8649 - val_loss: 0.3324 - val_categorical_accuracy: 0.8885
# Epoch 19/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2723 - categorical_accuracy: 0.8695 - val_loss: 0.3016 - val_categorical_accuracy: 0.8949
# Epoch 20/20
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2594 - categorical_accuracy: 0.8743 - val_loss: 0.2864 - val_categorical_accuracy: 0.9052
#               precision    recall  f1-score   support
#
#       ARCHER       0.96      0.88      0.92      2111
#       TUCKER       0.93      0.90      0.92      1053
#        T'POL       0.93      0.87      0.90      1101
#         REED       0.84      0.90      0.87       637
#        PHLOX       0.87      0.96      0.91       462
#        HOSHI       0.83      0.92      0.88       326
#       TRAVIS       0.84      0.91      0.87       308
#        SHRAN       0.60      1.00      0.75       110
#        DEGRA       0.65      0.99      0.78        79
#        SOVAL       0.71      1.00      0.83        53
#
#     accuracy                           0.90      6240
#    macro avg       0.82      0.93      0.86      6240
# weighted avg       0.91      0.90      0.90      6240
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f0035e1ca90>

# %% [markdown]
# **The Animated Series**

# %%
labels, predictions, target_names, history = train_and_evaluate("TAS", word_vectors)
print(classification_report(labels, predictions, target_names=target_names))
print(plot_confusion_matrix(labels, predictions, target_names))
plot_history(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 93, 300)           1294200
#
#  spatial_dropout1d_5 (Spatia  (None, 93, 300)          0
#  lDropout1D)
#
#  conv1d_5 (Conv1D)           (None, 91, 256)           230656
#
#  global_max_pooling1d_5 (Glo  (None, 256)              0
#  balMaxPooling1D)
#
#  dense_5 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 1,527,426
# Trainable params: 1,527,426
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 67/67 [==============================] - 1s 7ms/step - loss: 2.3818 - categorical_accuracy: 0.0415 - val_loss: 2.2435 - val_categorical_accuracy: 0.2098
# Epoch 2/20
# 67/67 [==============================] - 0s 5ms/step - loss: 2.0145 - categorical_accuracy: 0.3563 - val_loss: 1.7823 - val_categorical_accuracy: 0.6295
# Epoch 3/20
# 67/67 [==============================] - 0s 5ms/step - loss: 1.6956 - categorical_accuracy: 0.5177 - val_loss: 1.5200 - val_categorical_accuracy: 0.6429
# Epoch 4/20
# 67/67 [==============================] - 0s 5ms/step - loss: 1.2970 - categorical_accuracy: 0.6507 - val_loss: 1.1862 - val_categorical_accuracy: 0.7009
# Epoch 5/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.9258 - categorical_accuracy: 0.7206 - val_loss: 0.8970 - val_categorical_accuracy: 0.7946
# Epoch 6/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.6236 - categorical_accuracy: 0.7868 - val_loss: 0.8193 - val_categorical_accuracy: 0.7946
# Epoch 7/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.4622 - categorical_accuracy: 0.8298 - val_loss: 0.6201 - val_categorical_accuracy: 0.8571
# Epoch 8/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.3202 - categorical_accuracy: 0.8862 - val_loss: 0.4715 - val_categorical_accuracy: 0.8616
# Epoch 9/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2722 - categorical_accuracy: 0.8960 - val_loss: 0.2923 - val_categorical_accuracy: 0.9196
# Epoch 10/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2130 - categorical_accuracy: 0.9146 - val_loss: 0.1920 - val_categorical_accuracy: 0.9554
# Epoch 11/20
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1837 - categorical_accuracy: 0.9314 - val_loss: 0.1727 - val_categorical_accuracy: 0.9643
# Epoch 12/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1574 - categorical_accuracy: 0.9366 - val_loss: 0.1447 - val_categorical_accuracy: 0.9688
# Epoch 13/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1219 - categorical_accuracy: 0.9566 - val_loss: 0.1783 - val_categorical_accuracy: 0.9420
# Epoch 14/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1040 - categorical_accuracy: 0.9580 - val_loss: 0.1140 - val_categorical_accuracy: 0.9688
# Epoch 15/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0996 - categorical_accuracy: 0.9571 - val_loss: 0.1370 - val_categorical_accuracy: 0.9554
# Epoch 16/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1035 - categorical_accuracy: 0.9636 - val_loss: 0.1062 - val_categorical_accuracy: 0.9688
# Epoch 17/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0936 - categorical_accuracy: 0.9683 - val_loss: 0.1218 - val_categorical_accuracy: 0.9643
# Epoch 18/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1043 - categorical_accuracy: 0.9664 - val_loss: 0.0731 - val_categorical_accuracy: 0.9866
# Epoch 19/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0849 - categorical_accuracy: 0.9688 - val_loss: 0.0605 - val_categorical_accuracy: 0.9866
# Epoch 20/20
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0749 - categorical_accuracy: 0.9743 - val_loss: 0.0676 - val_categorical_accuracy: 0.9821
#               precision    recall  f1-score   support
#
#         KIRK       1.00      0.98      0.99       335
#        SPOCK       1.00      0.98      0.99       168
#        MCCOY       0.99      0.99      0.99        81
#        SCOTT       0.98      0.96      0.97        56
#         SULU       0.96      0.92      0.94        53
#        UHURA       0.92      0.97      0.94        35
#       CHAPEL       0.63      1.00      0.77        12
#         MUDD       0.90      1.00      0.95         9
#     COMPUTER       1.00      1.00      1.00         9
#      Y SPOCK       0.67      1.00      0.80        10
#
#     accuracy                           0.97       768
#    macro avg       0.90      0.98      0.93       768
# weighted avg       0.98      0.97      0.98       768
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7effb300a250>
